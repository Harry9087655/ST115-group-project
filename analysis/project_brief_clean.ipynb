# %% [markdown]
# # Does the Global South Receive Less Guardian Coverage as Crises Get More Serious?

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# 1. Introduction
#
# 2. Data Acquisition
#
# 3. Preparation for Data Analysis
#
# 4. Exploratory Data Analysis
#
# 5. Conclusion

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# The past decade has seen a succession of major conflict outbreaks — from the Syrian civil war and the Tigray conflict in Ethiopia, to the Russian invasion of Ukraine in 2022 and the escalation of violence in Sudan and Gaza in 2023. These crises have tested how global media allocates attention, and whether that allocation reflects the scale of human suffering or something else entirely.
#
# Media coverage of global crises shapes public awareness and, in turn, political and humanitarian response. If a newspaper's coverage is disproportionately concentrated on Western conflicts, regardless of their relative severity, this has real implications for how its readership understands and prioritises global suffering. The Guardian is a particularly meaningful case study: it has an explicit editorial commitment to international reporting and positions itself as a progressive outlet with global reach.
#
# The concept of proximity bias in journalism is well-established in media studies literature: outlets tend to devote more coverage to geographically or culturally proximate events. However, existing work is largely qualitative or limited to specific conflicts. No publicly available analysis applies a severity-controlled, data-driven framework to Guardian coverage across a decade-long window. The originality of this project lies in using ACLED fatality data as a quantitative severity benchmark, allowing us to ask not just "who gets covered?" but "who gets covered relative to how serious their crisis is?"

# %% [markdown]
# ### Research Questions

# %% [markdown]
# 1. Is there a measurable disparity in Guardian coverage volume between Global South and Western countries, controlling for conflict severity?
#
# 2. Do structural features of articles — length and section placement — differ systematically by region?
#
# 3. When The Guardian covers Global South crises, whose expertise does it centre, local professionals or Western commentators?
#
# 4. Does The Guardian respond to casualty spikes differently depending on region, and has any disparity narrowed or widened over time (2015–2024)?

# %% [markdown]
# ## 2. Data Acquisition

# %% [markdown]
# We use 4 data sources:
#
# - Guardian API (primary): Article metadata for all countries with recorded conflict, 2015–2024
#
# - Gemini API (primary):
#
# - ACLED Data (supplementary): Reported fatalities by country-year, used as our conflict severity proxy, link provided: ?
#
# - Our World in Data / World Bank (supplementary): Country income classification, used to assign Global South / Western labels, link provided: ?

# %%
import requests
import pandas as pd
import json
import time
import os
import numpy as np
from pathlib import Path

with open("../keys.json") as f:
    keys = json.load(f)

API_KEYS = [
    keys["guardian"]["api_key_1"],
    keys["guardian"]["api_key_2"],
    keys["guardian"]["api_key_3"]
]

# %% [markdown]
# ### 2.1 Guardian API
#
# We query the Guardian's search endpoint for every country present in the ACLED dataset. Country names are converted to Guardian tag slugs programmatically, with a manual corrections dictionary for edge cases. USA, UK, and Australia are queried by section rather than tag, as they have dedicated top-level sections on the Guardian.
#
# For each article we collect: publication date, section name, word count, article title, editorial pillar, and author byline.

# %% [markdown]
# ## 3. Preparation for Data Analysis (IDA)

# %% [markdown]
# ## 4. Exploratory Dara Analysis (EDA)

# %% [markdown]
# ## Conclusion
